# %% [markdown]
# # Santander Dev Week 2023 (ETL com Python)

# %% [markdown]
# **Contexto:** Você é um cientista de dados no Santander e recebeu a tarefa de envolver seus clientes de maneira mais personalizada. Seu objetivo é usar funçoes python  para criar mensagens de marketing personalizadas que serão entregues a cada cliente.
#
# **Condições do Problema:**
#
# 1. Você recebeu uma planilha simples, em formato XLSX ('dataset-vendas.xlsx'), apresentando tipos  de produtos e seus valores:
#  '''
#  -- Ebook
#  -- Livro
#
# '''
#
# 2. Irá desenvolver um imposto de 10% para Tipo Ebook, e 15% para Livro, assim tendo uma coluna com os valores respectivos de cada item ao imposto. Fazendo as devidas transformações.
#
# 3. Ao final desta manipulação, o  usuario digitara qual tipo de produto comprou e qual valor da compra, assim retornara uma msg do valor do imposto e sem, dependendo do seu Tipo.

# %% [markdown]
# ## Extração

# %%
from pandas.io.excel import read_excel
import pandas as pd

df = read_excel('/content/dataset-vendas - Copia.xlsx')
df
# Out:
#     Codigo do produto                                    Nome do produto  \
# 0             1000889               Desmistificando Business Inteligence
# 1             1002334                                         BI na veia
# 2             1002767     Power BI: 10 dicas para o tratamento dos dados
# 3             1004327                      Tudo sobre o Power BI Desktop
# 4             1013793                                     O poder do DAX
# 5             1022450                          A bruxaria da linguagem M
# 6             1037797                                       DAX avançado
# 7             1041119                                Top 10 fórmulas DAX
# 8             1078680                              Dashboards brilhantes
# 9             1086543                                   M e suas nuances
# 10            1096818                             Primeiros passos com M
# 11            1101035                                 BI para iniciantes
# 12             231776                           Primeiros passos com DAX
# 13             243083                                  Performance com M
# 14            3000001                     Publicando um relatório na web
# 15             326779                                SQL para iniciantes
# 16             394479                          Direct query com Power BI
# 17            4000001             Desenvolvendo dashboards profissionais
# 18             479745                    Os segredos do Power BI Desktop
# 19             520380       Conhecendo as linguagens do Power BI Desktop
# 20             695594                    Analizando dados com o Power BI
# 21             723457                       Utilizando o Power BI Helper
# 22             746596                                     ETL na prática
# 23             773912                           Power BI para iniciantes
# 24             783663                            Tudo sobre o DAX Studio
# 25             788975  Power BI Desktop: Desenvolvendo seus próprios ...
# 26             826490                              Funções DAX incríveis
# 27             838819                                      BI na íntegra
#
#      Tipo    Preço
# 0   Ebook   6.3090
# 1   Livro  42.0000
# 2   Ebook   8.4100
# 3   Livro  35.0000
# 4   Livro  24.0100
# 5   Livro  38.0120
# 6   Livro  27.0000
# 7   Ebook   4.9040
# 8   Ebook   5.1795
# 9   Livro  25.9900
# 10  Ebook   7.7105
# 11  Livro  36.0000
# 12  Ebook  13.3120
# 13  Livro  47.0000
# 14  Ebook   9.2500
# 15  Livro  32.0000
# 16  Ebook   8.4090
# 17  Livro  20.0000
# 18  Ebook   5.0000
# 19  Livro  48.9900
# 20  Livro  28.5120
# 21  Ebook   4.9120
# 22  Livro  19.5050
# 23  Livro  21.0000
# 24  Ebook   7.7090
# 25  Livro  18.0110
# 26  Ebook   6.3105
# 27  Livro  19.8700

# %% [markdown]
# ## Transformação

# %%
# Renomeando as colunas, e arredondado Preço para duas casas decimais.
df.columns = ["Id_produto", "Nome_produto", "Tipo", "Preco"]
df
# Out:
#     Id_produto                                       Nome_produto   Tipo  \
# 0      1000889               Desmistificando Business Inteligence  Ebook
# 1      1002334                                         BI na veia  Livro
# 2      1002767     Power BI: 10 dicas para o tratamento dos dados  Ebook
# 3      1004327                      Tudo sobre o Power BI Desktop  Livro
# 4      1013793                                     O poder do DAX  Livro
# 5      1022450                          A bruxaria da linguagem M  Livro
# 6      1037797                                       DAX avançado  Livro
# 7      1041119                                Top 10 fórmulas DAX  Ebook
# 8      1078680                              Dashboards brilhantes  Ebook
# 9      1086543                                   M e suas nuances  Livro
# 10     1096818                             Primeiros passos com M  Ebook
# 11     1101035                                 BI para iniciantes  Livro
# 12      231776                           Primeiros passos com DAX  Ebook
# 13      243083                                  Performance com M  Livro
# 14     3000001                     Publicando um relatório na web  Ebook
# 15      326779                                SQL para iniciantes  Livro
# 16      394479                          Direct query com Power BI  Ebook
# 17     4000001             Desenvolvendo dashboards profissionais  Livro
# 18      479745                    Os segredos do Power BI Desktop  Ebook
# 19      520380       Conhecendo as linguagens do Power BI Desktop  Livro
# 20      695594                    Analizando dados com o Power BI  Livro
# 21      723457                       Utilizando o Power BI Helper  Ebook
# 22      746596                                     ETL na prática  Livro
# 23      773912                           Power BI para iniciantes  Livro
# 24      783663                            Tudo sobre o DAX Studio  Ebook
# 25      788975  Power BI Desktop: Desenvolvendo seus próprios ...  Livro
# 26      826490                              Funções DAX incríveis  Ebook
# 27      838819                                      BI na íntegra  Livro
#
#       Preco
# 0    6.3090
# 1   42.0000
# 2    8.4100
# 3   35.0000
# 4   24.0100
# 5   38.0120
# 6   27.0000
# 7    4.9040
# 8    5.1795
# 9   25.9900
# 10   7.7105
# 11  36.0000
# 12  13.3120
# 13  47.0000
# 14   9.2500
# 15  32.0000
# 16   8.4090
# 17  20.0000
# 18   5.0000
# 19  48.9900
# 20  28.5120
# 21   4.9120
# 22  19.5050
# 23  21.0000
# 24   7.7090
# 25  18.0110
# 26   6.3105
# 27  19.8700

# %%
# Define o índice como a coluna 'Id_Produto'
df.set_index('Id_produto', inplace=True)

# Remove o índice e não mantém o índice anterior como uma coluna
df_reset = df.reset_index(drop=True)

# Exibe o DataFrame resultante
df
# Out:
#                                                  Nome_produto   Tipo    Preco
# Id_produto
# 1000889                  Desmistificando Business Inteligence  Ebook   6.3090
# 1002334                                            BI na veia  Livro  42.0000
# 1002767        Power BI: 10 dicas para o tratamento dos dados  Ebook   8.4100
# 1004327                         Tudo sobre o Power BI Desktop  Livro  35.0000
# 1013793                                        O poder do DAX  Livro  24.0100
# 1022450                             A bruxaria da linguagem M  Livro  38.0120
# 1037797                                          DAX avançado  Livro  27.0000
# 1041119                                   Top 10 fórmulas DAX  Ebook   4.9040
# 1078680                                 Dashboards brilhantes  Ebook   5.1795
# 1086543                                      M e suas nuances  Livro  25.9900
# 1096818                                Primeiros passos com M  Ebook   7.7105
# 1101035                                    BI para iniciantes  Livro  36.0000
# 231776                               Primeiros passos com DAX  Ebook  13.3120
# 243083                                      Performance com M  Livro  47.0000
# 3000001                        Publicando um relatório na web  Ebook   9.2500
# 326779                                    SQL para iniciantes  Livro  32.0000
# 394479                              Direct query com Power BI  Ebook   8.4090
# 4000001                Desenvolvendo dashboards profissionais  Livro  20.0000
# 479745                        Os segredos do Power BI Desktop  Ebook   5.0000
# 520380           Conhecendo as linguagens do Power BI Desktop  Livro  48.9900
# 695594                        Analizando dados com o Power BI  Livro  28.5120
# 723457                           Utilizando o Power BI Helper  Ebook   4.9120
# 746596                                         ETL na prática  Livro  19.5050
# 773912                               Power BI para iniciantes  Livro  21.0000
# 783663                                Tudo sobre o DAX Studio  Ebook   7.7090
# 788975      Power BI Desktop: Desenvolvendo seus próprios ...  Livro  18.0110
# 826490                                  Funções DAX incríveis  Ebook   6.3105
# 838819                                          BI na íntegra  Livro  19.8700

# %%
def calcular_imposto(tipo, preco):
    tipo = tipo.lower()  # Converte a entrada do usuário para letras minúsculas, assim usuário podera digitar tanto maiuscula, quanto minúsculo.
    if tipo == 'ebook':
        return preco * 0.10
    elif tipo == 'livro':
        return preco * 0.15
    else:
        return 0.0

# Solicitar ao usuário o tipo de produto e preço
tipo_produto = input("Digite o tipo de produto (Livro ou Ebook): ")
preco_produto = float(input("Digite o preço do produto: "))

# Calcular o imposto,e o valor total com imposto
imposto = calcular_imposto(tipo_produto, preco_produto)
valor_com_imposto = preco_produto + imposto

# Criar a mensagem de retorno
mensagem = f"Você comprou um {tipo_produto}.\n"
mensagem += f"Valor sem imposto: R${preco_produto:.2f}\n"
mensagem += f"Valor com imposto: R${valor_com_imposto:.2f}"
print(mensagem)

# Criar coluna Imposto
df['Imposto'] = df.apply(lambda row: calcular_imposto(row['Tipo'], row['Preco']), axis=1)



# Transforma as colunas 'Preco' e 'Imposto' em reais
df['Preco'] = df['Preco'].apply(lambda x: f"R${x:.2f}")
df['Imposto'] = df['Imposto'].apply(lambda x: f"R${x:.2f}")

# Exiba o DataFrame com as colunas formatadas
df
# Out:
# Digite o tipo de produto (Livro ou Ebook): livro
# Digite o preço do produto: 42.00
# Você comprou um livro.
# Valor sem imposto: R$42.00
# Valor com imposto: R$48.30
#                                                  Nome_produto   Tipo    Preco  \
# Id_produto
# 1000889                  Desmistificando Business Inteligence  Ebook   R$6.31
# 1002334                                            BI na veia  Livro  R$42.00
# 1002767        Power BI: 10 dicas para o tratamento dos dados  Ebook   R$8.41
# 1004327                         Tudo sobre o Power BI Desktop  Livro  R$35.00
# 1013793                                        O poder do DAX  Livro  R$24.01
# 1022450                             A bruxaria da linguagem M  Livro  R$38.01
# 1037797                                          DAX avançado  Livro  R$27.00
# 1041119                                   Top 10 fórmulas DAX  Ebook   R$4.90
# 1078680                                 Dashboards brilhantes  Ebook   R$5.18
# 1086543                                      M e suas nuances  Livro  R$25.99
# 1096818                                Primeiros passos com M  Ebook   R$7.71
# 1101035                                    BI para iniciantes  Livro  R$36.00
# 231776                               Primeiros passos com DAX  Ebook  R$13.31
# 243083                                      Performance com M  Livro  R$47.00
# 3000001                        Publicando um relatório na web  Ebook   R$9.25
# 326779                                    SQL para iniciantes  Livro  R$32.00
# 394479                              Direct query com Power BI  Ebook   R$8.41
# 4000001                Desenvolvendo dashboards profissionais  Livro  R$20.00
# 479745                        Os segredos do Power BI Desktop  Ebook   R$5.00
# 520380           Conhecendo as linguagens do Power BI Desktop  Livro  R$48.99
# 695594                        Analizando dados com o Power BI  Livro  R$28.51
# 723457                           Utilizando o Power BI Helper  Ebook   R$4.91
# 746596                                         ETL na prática  Livro  R$19.50
# 773912                               Power BI para iniciantes  Livro  R$21.00
# 783663                                Tudo sobre o DAX Studio  Ebook   R$7.71
# 788975      Power BI Desktop: Desenvolvendo seus próprios ...  Livro  R$18.01
# 826490                                  Funções DAX incríveis  Ebook   R$6.31
# 838819                                          BI na íntegra  Livro  R$19.87
#
#            Imposto
# Id_produto
# 1000889     R$0.63
# 1002334     R$6.30
# 1002767     R$0.84
# 1004327     R$5.25
# 1013793     R$3.60
# 1022450     R$5.70
# 1037797     R$4.05
# 1041119     R$0.49
# 1078680     R$0.52
# 1086543     R$3.90
# 1096818     R$0.77
# 1101035     R$5.40
# 231776      R$1.33
# 243083      R$7.05
# 3000001     R$0.93
# 326779      R$4.80
# 394479      R$0.84
# 4000001     R$3.00
# 479745      R$0.50
# 520380      R$7.35
# 695594      R$4.28
# 723457      R$0.49
# 746596      R$2.93
# 773912      R$3.15
# 783663      R$0.77
# 788975      R$2.70
# 826490      R$0.63
# 838819      R$2.98

# %% [markdown]
# ## **L**oad

# %%
pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.10/dist-packages (3.1.2)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.10/dist-packages (from openpyxl) (1.1.0)

# %%
# Salvando o DataFrame em um arquivo Excel
df.to_excel('Vendas_produtos.xlsx', index=False, engine='openpyxl')

print("DataFrame salvo com sucesso em Vendas_produtos.xlsx")
# Out:
# DataFrame salvo com sucesso em Vendas_produtos.xlsx
